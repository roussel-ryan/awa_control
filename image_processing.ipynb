# %%
import h5py
import matplotlib.pyplot as plt

# %%
fname = 'pics/img_1632259715.8251882.h5'
with h5py.File(fname) as f:
    x = f['/raw_images'][:]
    print(f.attrs['ROI'])
# Out:
# [[ 774  301]
#  [1068  948]]

# %%
plt.imshow(x[0])
